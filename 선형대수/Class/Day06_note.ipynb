# %% [markdown]
# # 데이터 변환하기

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df2 = df

# %%
class_label = LabelEncoder()

# %%
sex = df2['Sex'].values

# %%
sex_new = class_label.fit_transform(sex)

# %%
df2['Sex'] = sex_new

# %%
class_label.classes_
# Out:
# array(['F', 'M'], dtype=object)

# %%
df2
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40    1           ATA        140          289          0     Normal
# 1     49    0           NAP        160          180          0     Normal
# 2     37    1           ATA        130          283          0         ST
# 3     48    0           ASY        138          214          0     Normal
# 4     54    1           NAP        150          195          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 913   45    1            TA        110          264          0     Normal
# 914   68    1           ASY        144          193          1     Normal
# 915   57    1           ASY        130          131          0     Normal
# 916   57    0           ATA        130          236          0        LVH
# 917   38    1           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df2.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
label2 = LabelEncoder()
new2 = df2['ChestPainType'].values
value2 = class_label.fit_transform(new2)
df2['ChestPainType'] = value2

# %%
label3 = LabelEncoder()
new3 = df2['RestingECG'].values
value3 = class_label.fit_transform(new3)
df2['RestingECG'] = value3

# %%
label4 = LabelEncoder()
new4 = df2['ExerciseAngina'].values
value4 = class_label.fit_transform(new4)
df2['ExerciseAngina'] = value4

# %%
label5 = LabelEncoder()
new5 = df2['ST_Slope'].values
value5 = class_label.fit_transform(new5)
df2['ST_Slope'] = value5

# %%
df2
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...

# %%
df2.to_csv('./data/heart_disease.csv')

# %% [markdown]
# vetorization이 정말 중요하다.
#
# 알고리즘을 맹신하면 안된다. 정확도의 문제면 안된다.

# %% [markdown]
# ---
#
# 머신러닝을 하기전에 데이터 표준화의 과정을 반드시 거쳐야 한다.
#
# 표준화 = (원데이터 - 평균) / 표준편차
#
# 평균0 표준편차1
#
# 세로로 피처의 각각의 평균과 표준편차를 구한다.
#
# 확률분포를 공부해야합니다아아...
#
# 머신러닝을 하든 데이터 분석을 하든 데이터는 무조건 흩어져있는게 좋다.

# %% [markdown]
# # 공분산행렬
#
# 피처 들간 얼마나 상관관계가 있냐 하는 것
#
# cov(X)를 구하는데 n은 n-1이어도 된다.

# %% [markdown]
# # 차원 축소 실습

# %%
df2
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...
